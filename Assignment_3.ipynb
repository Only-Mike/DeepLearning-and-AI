    quoted_sentences.append(quoted_sentence)

# %%
quoted_sentences
# Out:
# ['The Tsunami wave crashed against the raised houses and broke the pilings as if they were toothpicks',
#  'I became paranoid that the school of jellyfish was spying on me',
#  'It had been sixteen days since the zombies first attacked',
#  'If you like tuna and tomato sauce, try combining the two, it’s really not as bad as it sounds',
#  'Thirty years later, she still thought it was okay to put the toilet paper roll under rather than over',
#  'Garlic ice-cream was her favorite',
#  'I would have gotten the promotion, but my attendance wasn’t good enough',
#  'The underground bunker was filled with chips and candy',
#  'It took him a while to realize that everything he decided not to change, he was actually choosing',
#  "There's a reason that roses have thorns",
#  'It was difficult for Mary to admit that most of her workout consisted of exercising poor judgment',
#  'The thick foliage and intertwined vines made the hike nearly impossible',
# ...

# %%
# !pip install sentence-transformers -q
# !pip install gradio -q

# %%
from sentence_transformers import SentenceTransformer, util
import torch
import numpy as np
from sentence_transformers.util import cos_sim

#model = SentenceTransformer('bert-base-nli-mean-tokens')
model = SentenceTransformer('all-mpnet-base-v2')

model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
corpus_embeddings = model.encode(quoted_sentences, convert_to_tensor=True)


# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = min(5, len(quoted_sentences))
for query in sentences:
    query_embedding = model.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    
    #util.semantic_search to perform cosine similarty + topk
    hits = util.semantic_search(query_embedding, corpus_embeddings, top_k=5)
    hits = hits[0]      
    #Get the hits for the first query
    for hit in hits:
        print(quoted_sentences[hit['corpus_id']], "(Score: {:.4f})".format(hit['score']))
# Out:
# ...
#
#
# Query: The Tsunami wave crashed against the raised houses and broke the pilings as if they were toothpicks
#
# Top 5 most similar sentences in corpus:
# The Tsunami wave crashed against the raised houses and broke the pilings as if they were toothpicks (Score: 1.0000)
# The sound of the waves crashing against the shore was hypnotic (Score: 0.4303)
# The old rusted farm equipment surrounded the house predicting its demise (Score: 0.4212)
# The door slammed on the watermelon (Score: 0.3961)
# The shark-infested South Pine channel was the only way in or out (Score: 0.3682)
#
#
# ...
#
#
# Query:  I became paranoid that the school of jellyfish was spying on me
#
# Top 5 most similar sentences in corpus:
# I became paranoid that the school of jellyfish was spying on me (Score: 1.0000)
# I was starting to worry that my pet turtle could tell what I was thinking (Score: 0.4682)
# At that moment I was the most fearsome weasel in the entire swamp (Score: 0.4608)
# ...

# %%
def query_corpus(query):
  results = []
  query_embedding = model.encode(query, convert_to_tensor=True)
  cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
  top_results = torch.topk(cos_scores, k=top_k)
  for score, idx in zip(top_results[0], top_results[1]):
    results.append((quoted_sentences[idx], score))
    output = results[0][0]
    score = float(results[0][1].numpy())
  return output, score

# %%
query_corpus('I like to eat a pie')
# Out:
# ('There are few things better in life than a slice of pie', 0.6977846622467041)

# %%
import gradio as gr


gr.Interface(fn=query_corpus, inputs=["text"], outputs=["text", "label"]).launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
